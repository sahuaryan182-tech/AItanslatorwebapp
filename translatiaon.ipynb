# %% [markdown]
# <a href="https://colab.research.google.com/github/sahuaryan182-tech/AItanslatorwebapp/blob/main/translatiaon.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('welcome in google colabe')
# Out:
# welcome in google colabe

# %%
#crate language translation using hugging page from transformers
from transformers import MarianMTModel,MarianTokenizer
# to select he model name from hugging facr transformers
model_name = 'Helsinki-NLP/opus-mt-en-hi'
# to load the model using model name
model=MarianMTModel.from_pretrained(model_name)
# to load the tokonizer using model name
tokenizer=MarianTokenizer.from_pretrained(model_name)
# to get the input text from user to translate
prompt=input('enter the text to translate')
# to encodethe input text into input tokens using tokenizer
input_tokens=tokenizer(prompt, return_tensors='pt', padding=True)
# to genrate the output tokens using model and input tokens
output_tokens=model.generate(**input_tokens)
# to decode the output tokens into translated text
print(tokenizer.decode(output_tokens[0], skip_special_tokens=True))
# Out:
# Loading weights:   0%|          | 0/258 [00:00<?, ?it/s]
# The tied weights mapping and config for this model specifies to tie model.shared.weight to model.decoder.embed_tokens.weight, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning
# The tied weights mapping and config for this model specifies to tie model.shared.weight to model.encoder.embed_tokens.weight, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning
# enter the text to translatehow are you
# आप कैसे हैं

# %%
-
